# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_excel("data.xlsx")

# %%
df.head()
# Out:
#       User_ID  Age  Gender  Technology_Usage_Hours  Social_Media_Usage_Hours  \
# 0  USER-00001   23  Female                    6.57                      6.00
# 1  USER-00002   21    Male                    3.01                      2.57
# 2  USER-00003   51    Male                    3.04                      6.14
# 3  USER-00004   25  Female                    3.84                      4.48
# 4  USER-00005   53    Male                    1.20                      0.56
#
#    Gaming_Hours  Screen_Time_Hours Mental_Health_Status Stress_Level  \
# 0          0.68              12.36                 Good          Low
# 1          3.74               7.61                 Poor         High
# 2          1.26               3.16                 Fair         High
# 3          2.59              13.08            Excellent       Medium
# 4          0.29              12.63                 Good          Low
#
#    Sleep_Hours  Physical_Activity_Hours Support_Systems_Access  \
# ...

# %%
df.loc()

# %%
df["Screen_Time_Hours"].idxmax()
# Out:
# 1063

# %%
df.nlargest(10,"Screen_Time_Hours")
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 1063  USER-01064   61   Other                    5.75
# 1168  USER-01169   24   Other                    7.29
# 209   USER-00210   60    Male                    8.33
# 1157  USER-01158   33    Male                    5.45
# 1230  USER-01231   49  Female                    9.14
# 798   USER-00799   53   Other                    5.58
# 483   USER-00484   20    Male                    4.98
# 202   USER-00203   64  Female                    7.69
# 578   USER-00579   50  Female                    5.54
# 139   USER-00140   26  Female                   11.84
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours  \
# 1063                      1.98          4.25              15.00
# 1168                      2.36          3.14              15.00
# 209                       1.05          2.30              14.98
# 1157                      3.41          3.47              14.98
# ...

# %%
df.sort_values(by="Screen_Time_Hours",ascending=False).loc[:10]
# Out:
#          User_ID  Age  Gender  Technology_Usage_Hours  \
# 1063  USER-01064   61   Other                    5.75
# 1168  USER-01169   24   Other                    7.29
# 209   USER-00210   60    Male                    8.33
# 1157  USER-01158   33    Male                    5.45
# 1230  USER-01231   49  Female                    9.14
# 798   USER-00799   53   Other                    5.58
# 483   USER-00484   20    Male                    4.98
# 202   USER-00203   64  Female                    7.69
# 578   USER-00579   50  Female                    5.54
# 1415  USER-01416   29  Female                    3.31
# 1023  USER-01024   47    Male                   11.98
# 139   USER-00140   26  Female                   11.84
# 17    USER-00018   55  Female                    2.03
# 726   USER-00727   50    Male                    8.94
# 10    USER-00011   53   Other                    4.78
#
#       Social_Media_Usage_Hours  Gaming_Hours  Screen_Time_Hours  \
# ...

# %%
df.groupby(["Screen_Time_Hours","Sleep_Hours"]).apply(lambda x:x)
# Out:
#                                        User_ID  Age  Gender  \
# Screen_Time_Hours Sleep_Hours
# 1.01              8.36        426   USER-00427   54   Other
# 1.02              4.99        89    USER-00090   64  Female
# 1.03              5.67        1405  USER-01406   64  Female
#                   8.47        555   USER-00556   31  Female
# 1.04              7.94        474   USER-00475   60    Male
# ...                                        ...  ...     ...
# 14.98             4.31        209   USER-00210   60    Male
#                   4.92        1230  USER-01231   49  Female
#                   5.56        1157  USER-01158   33    Male
# 15.00             5.97        1063  USER-01064   61   Other
#                   6.33        1168  USER-01169   24   Other
#
#                                     Technology_Usage_Hours  \
# Screen_Time_Hours Sleep_Hours
# 1.01              8.36        426                     7.69
# 1.02              4.99        89                      3.10
# ...
